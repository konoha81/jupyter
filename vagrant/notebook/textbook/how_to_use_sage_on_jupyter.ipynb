# %%
# %%HTML
# <link rel="stylesheet" type="text/css" href="css/sage_table_form.css">
# Out:
# <link rel="stylesheet" type="text/css" href="css/sage_table_form.css">

# %%
# python2.7カーネルでsageの関数を使う
# %load_ext sage
# jupyter用のdisplayメソッド
from IPython.display import display, Latex, HTML, Math, JSON
# テンプレートエンジン
load('script/JinjaMagics.py')
# ユーティリティ
load('script/sage_util.py')
# Out:
# The sage extension is already loaded. To reload it, use:
#   %reload_ext sage

# %%
hdr=["円周率", "自然体数の底", "虚数単位", "無限大"]
sts=[pi, e, I, oo]

# %%
# %%capture output
html.table([(h, str(st), "$%s$"%latex(st) ) for (h, st) in zip(hdr, sts)])

# %%
HTML(output.stdout)
# Out:
# <div class="notruncate">
# <table  class="table_form">
# <tbody>
# <tr class ="row-a">
# <td>円周率</td>
# <td>pi</td>
# <td><script type="math/tex">\pi</script></td>
# </tr>
# <tr class ="row-b">
# <td>自然体数の底</td>
# <td>e</td>
# <td><script type="math/tex">e</script></td>
# </tr>
# <tr class ="row-a">
# <td>虚数単位</td>
# <td>I</td>
# <td><script type="math/tex">i</script></td>
# </tr>
# <tr class ="row-b">
# <td>無限大</td>
# <td>+Infinity</td>
# <td><script type="math/tex">+\infty</script></td>
# </tr>
# </tbody>
# </table>
# </div>

# %%
pp({'test':'あ'})
# Out:
# {
#     "test": "あ"
# }

# %%
s_plt = plot(sin(x), [x, -pi, pi], figsize=4)
c_plt = plot(cos(x), [x, -pi, pi], figsize=4)

# %%
# %%capture output
html.table([[_to_png(s_plt), _to_png(c_plt)]], header=["sin", "cos"])

# %%
HTML(output.stdout)
# Out:
# <div class="notruncate">
# <table  class="table_form">
# <tbody>
# <tr>
# <th>sin</th>
# <th>cos</th>
# </tr>
# <tr class ="row-a">
# <td><img src='data:image/png;base64,...'/></td>
# <td><img src='data:image/png;base64,...'/></td>
# </tr>
# </tbody>
# </table>
# </div>

# %%
Graphics2Html(c_plt)
# Out:
# <__main__.Graphics2Html instance at 0x7f5318c25098>

# %%
a = 1/2 + 1/3
Math(latex(a))
# Out:
# $$\frac{5}{6}$$

# %%
x = var('x')
f(x) = x^3 - x^2 - 2*x
Math(latex(f(x)))
# Out:
# $$x^{3} - x^{2} - 2 \, x$$

# %%
Table2Html([[_to_png(s_plt), _to_png(c_plt)]], header=["sin", "cos"])
# Out:
# <__main__.Table2Html instance at 0x7f5318d0fef0>
